# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('crimeEdited.csv', encoding= 'unicode_escape')

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING OCCURRED_ON_DATE  YEAR  MONTH  ...  \
# 0      D14            808      NaN   9/2/2018 13:00  2018      9  ...
# 1      C11            347      NaN   8/21/2018 0:00  2018      8  ...
# 2       D4            151      NaN   9/3/2018 19:27  2018      9  ...
# 3       D4            272      NaN   9/3/2018 21:16  2018      9  ...
# 4       B3            421      NaN   9/3/2018 21:05  2018      9  ...
#
#   Unnamed: 18  OCCURRED_ON_DATE.1 Unnamed: 20 Unnamed: 21  Temp_High  rain  \
# ...

# %%
df.drop('Unnamed: 26',inplace = True, axis = 1)

# %%
df.drop('Unnamed: 27', inplace = True, axis = 1)

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING OCCURRED_ON_DATE  YEAR  MONTH  ...  \
# 0      D14            808      NaN   9/2/2018 13:00  2018      9  ...
# 1      C11            347      NaN   8/21/2018 0:00  2018      8  ...
# 2       D4            151      NaN   9/3/2018 19:27  2018      9  ...
# 3       D4            272      NaN   9/3/2018 21:16  2018      9  ...
# 4       B3            421      NaN   9/3/2018 21:05  2018      9  ...
#
#                       Location  Unnamed: 17 Unnamed: 18 OCCURRED_ON_DATE.1  \
# ...

# %%
df.drop('Unnamed: 17', inplace = True, axis = 1)

# %%
df.drop('Unnamed: 18', inplace = True, axis = 1)

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING OCCURRED_ON_DATE  YEAR  MONTH  ...  \
# 0      D14            808      NaN   9/2/2018 13:00  2018      9  ...
# 1      C11            347      NaN   8/21/2018 0:00  2018      8  ...
# 2       D4            151      NaN   9/3/2018 19:27  2018      9  ...
# 3       D4            272      NaN   9/3/2018 21:16  2018      9  ...
# 4       B3            421      NaN   9/3/2018 21:05  2018      9  ...
#
#          Lat       Long                     Location OCCURRED_ON_DATE.1  \
# ...

# %%
df.drop('Lat', inplace = True, axis = 1)

# %%
df.drop('Long', inplace = True, axis = 1)

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING OCCURRED_ON_DATE  YEAR  MONTH  ...  \
# 0      D14            808      NaN   9/2/2018 13:00  2018      9  ...
# 1      C11            347      NaN   8/21/2018 0:00  2018      8  ...
# 2       D4            151      NaN   9/3/2018 19:27  2018      9  ...
# 3       D4            272      NaN   9/3/2018 21:16  2018      9  ...
# 4       B3            421      NaN   9/3/2018 21:05  2018      9  ...
#
#      UCR_PART       STREET                     Location OCCURRED_ON_DATE.1  \
# ...

# %%
df.drop('OCCURRED_ON_DATE', inplace = True, axis = 1)

# %%
df.drop('UCR_PART', inplace = True, axis = 1)

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 0      D14            808      NaN  2018      9      Sunday    13
# 1      C11            347      NaN  2018      8     Tuesday     0
# 2       D4            151      NaN  2018      9      Monday    19
# 3       D4            272      NaN  2018      9      Monday    21
# 4       B3            421      NaN  2018      9      Monday    21
#
#         STREET                     Location OCCURRED_ON_DATE.1 Unnamed: 20  \
# ...

# %%
#df.to_csv('removed.csv')

# %%
df.drop_duplicates(subset="INCIDENT_NUMBER", keep=False, inplace=True)

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 0      D14            808      NaN  2018      9      Sunday    13
# 1      C11            347      NaN  2018      8     Tuesday     0
# 2       D4            151      NaN  2018      9      Monday    19
# 3       D4            272      NaN  2018      9      Monday    21
# 4       B3            421      NaN  2018      9      Monday    21
#
#         STREET                     Location OCCURRED_ON_DATE.1 Unnamed: 20  \
# ...

# %%
#df.to_csv('CleanedCrimeData.csv')
