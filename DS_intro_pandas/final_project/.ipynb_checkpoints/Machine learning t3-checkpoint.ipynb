# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('CleanedCrimeData.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0           0      I182070945           619               Larceny
# 1           1      I182070943          1402             Vandalism
# 2           2      I182070941          3410                 Towed
# 3           3      I182070940          3114  Investigate Property
# 4           4      I182070938          3114  Investigate Property
#
#     OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  YEAR  MONTH  ...  \
# 0    LARCENY ALL OTHERS      D14            808      NaN  2018      9  ...
# 1             VANDALISM      C11            347      NaN  2018      8  ...
# 2   TOWED MOTOR VEHICLE       D4            151      NaN  2018      9  ...
# 3  INVESTIGATE PROPERTY       D4            272      NaN  2018      9  ...
# 4  INVESTIGATE PROPERTY       B3            421      NaN  2018      9  ...
#
#   HOUR       STREET                     Location OCCURRED_ON_DATE.1  \
# 0   13   LINCOLN ST  (42.35779134, -71.13937053)           9/2/2018
# 1    0     HECLA ST  (42.30682138, -71.06030035)          8/21/2018
# 2   19  CAZENOVE ST  (42.34658879, -71.07242943)           9/3/2018
# 3   21   NEWCOMB ST  (42.33418175, -71.07866441)           9/3/2018
# 4   21     DELHI ST  (42.27536542, -71.09036101)           9/3/2018
#
#   Unnamed: 20 Unnamed: 21 Temp_High  rain snow Temp_low
# 0     1:00:00          PM      84.0     0    0     64.0
# 1    12:00:00          AM      72.0     0    0     64.9
# 2     7:27:00          PM      96.1     0    0     73.0
# 3     9:16:00          PM      96.1     0    0     73.0
# 4     9:05:00          PM      96.1     0    0     73.0
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255006 entries, 0 to 255005
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           255006 non-null  int64
#  1   INCIDENT_NUMBER      255006 non-null  object
#  2   OFFENSE_CODE         255006 non-null  int64
#  3   OFFENSE_CODE_GROUP   255006 non-null  object
#  4   OFFENSE_DESCRIPTION  255006 non-null  object
#  5   DISTRICT             253559 non-null  object
#  6   REPORTING_AREA       255006 non-null  object
#  7   SHOOTING             398 non-null     object
#  8   YEAR                 255006 non-null  int64
#  9   MONTH                255006 non-null  int64
#  10  DAY_OF_WEEK          255006 non-null  object
#  11  HOUR                 255006 non-null  int64
#  12  STREET               246846 non-null  object
#  13  Location             255006 non-null  object
#  14  OCCURRED_ON_DATE.1   255006 non-null  object
#  15  Unnamed: 20          255006 non-null  object
#  16  Unnamed: 21          255006 non-null  object
#  17  Temp_High            254788 non-null  float64
#  18  rain                 254788 non-null  object
#  19  snow                 254788 non-null  object
#  20  Temp_low             254788 non-null  float64
# dtypes: float64(2), int64(5), object(14)
# memory usage: 40.9+ MB

# %%
df2 = df[["Temp_High", 'rain', 'OCCURRED_ON_DATE.1', 'Temp_low', 'snow']]
df2['Temp_High'] = df2['Temp_High'].round(-1)
df2.head(20)
# Out:
# C:\Users\19138\AppData\Local\Temp/ipykernel_40060/264981201.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Temp_High'] = df2['Temp_High'].round(-1)
#     Temp_High rain OCCURRED_ON_DATE.1  Temp_low snow
# 0        80.0    0           9/2/2018      64.0    0
# 1        70.0    0          8/21/2018      64.9    0
# 2       100.0    0           9/3/2018      73.0    0
# 3       100.0    0           9/3/2018      73.0    0
# 4       100.0    0           9/3/2018      73.0    0
# 5       100.0    0           9/3/2018      73.0    0
# 6       100.0    0           9/3/2018      73.0    0
# 7       100.0    0           9/3/2018      73.0    0
# 8       100.0    0           9/3/2018      73.0    0
# 9       100.0    0           9/3/2018      73.0    0
# 10      100.0    0           9/3/2018      73.0    0
# 11      100.0    0           9/3/2018      73.0    0
# 12      100.0    0           9/3/2018      73.0    0
# 13      100.0    0           9/3/2018      73.0    0
# 14       80.0    0           9/2/2018      64.0    0
# 15      100.0    0           9/3/2018      73.0    0
# 16      100.0    0           9/3/2018      73.0    0
# 17      100.0    0           9/3/2018      73.0    0
# 18      100.0    0           9/3/2018      73.0    0
# 19       80.0    0           9/2/2018      64.0    0

# %%
df2['rain'] = pd.to_numeric(df['rain'], errors='coerce')
df2['snow'] = pd.to_numeric(df['snow'], errors='coerce')
# Out:
# C:\Users\19138\AppData\Local\Temp/ipykernel_40060/1390764940.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['rain'] = pd.to_numeric(df['rain'], errors='coerce')
# C:\Users\19138\AppData\Local\Temp/ipykernel_40060/1390764940.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['snow'] = pd.to_numeric(df['snow'], errors='coerce')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255006 entries, 0 to 255005
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Temp_High           254788 non-null  float64
#  1   rain                224973 non-null  float64
#  2   OCCURRED_ON_DATE.1  255006 non-null  object
#  3   Temp_low            254788 non-null  float64
#  4   snow                239722 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 9.7+ MB

# %%
df2.drop_duplicates(subset="OCCURRED_ON_DATE.1", keep='first', inplace=True)
# Out:
# C:\Users\19138\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1177 entries, 0 to 245570
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Temp_High           1176 non-null   float64
#  1   rain                1040 non-null   float64
#  2   OCCURRED_ON_DATE.1  1177 non-null   object
#  3   Temp_low            1176 non-null   float64
#  4   snow                1102 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 55.2+ KB

# %%
df2.head()
# Out:
#     Temp_High  rain OCCURRED_ON_DATE.1  Temp_low  snow
# 0        80.0   0.0           9/2/2018      64.0   0.0
# 1        70.0   0.0          8/21/2018      64.9   0.0
# 2       100.0   0.0           9/3/2018      73.0   0.0
# 38       70.0   0.0           9/1/2018      63.0   0.0
# 48       70.0   0.0          8/31/2018      63.0   0.0

# %%
df3 = df
df3['Date'] = df['OCCURRED_ON_DATE.1']
df3.head()
# Out:
#    Unnamed: 0 INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0           0      I182070945           619               Larceny
# 1           1      I182070943          1402             Vandalism
# 2           2      I182070941          3410                 Towed
# 3           3      I182070940          3114  Investigate Property
# 4           4      I182070938          3114  Investigate Property
#
#     OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  YEAR  MONTH  ...  \
# 0    LARCENY ALL OTHERS      D14            808      NaN  2018      9  ...
# 1             VANDALISM      C11            347      NaN  2018      8  ...
# 2   TOWED MOTOR VEHICLE       D4            151      NaN  2018      9  ...
# 3  INVESTIGATE PROPERTY       D4            272      NaN  2018      9  ...
# 4  INVESTIGATE PROPERTY       B3            421      NaN  2018      9  ...
#
#         STREET                     Location OCCURRED_ON_DATE.1 Unnamed: 20  \
# 0   LINCOLN ST  (42.35779134, -71.13937053)           9/2/2018     1:00:00
# 1     HECLA ST  (42.30682138, -71.06030035)          8/21/2018    12:00:00
# 2  CAZENOVE ST  (42.34658879, -71.07242943)           9/3/2018     7:27:00
# 3   NEWCOMB ST  (42.33418175, -71.07866441)           9/3/2018     9:16:00
# 4     DELHI ST  (42.27536542, -71.09036101)           9/3/2018     9:05:00
#
#   Unnamed: 21 Temp_High rain  snow Temp_low       Date
# 0          PM      84.0    0     0     64.0   9/2/2018
# 1          AM      72.0    0     0     64.9  8/21/2018
# 2          PM      96.1    0     0     73.0   9/3/2018
# 3          PM      96.1    0     0     73.0   9/3/2018
# 4          PM      96.1    0     0     73.0   9/3/2018
#
# [5 rows x 22 columns]

# %%
day = df.pivot_table(columns=['OCCURRED_ON_DATE.1'], aggfunc='size')
print(day)
# Out:
# OCCURRED_ON_DATE.1
# 1/1/2016     280
# 1/1/2017     209
# 1/1/2018     212
# 1/10/2016    157
# 1/10/2017    217
#             ...
# 9/8/2016     206
# 9/8/2017     285
# 9/9/2015     243
# 9/9/2016     236
# 9/9/2017     213
# Length: 1177, dtype: int64

# %%
df4 = day.reset_index()
df4
# Out:
#      OCCURRED_ON_DATE.1    0
# 0              1/1/2016  280
# 1              1/1/2017  209
# 2              1/1/2018  212
# 3             1/10/2016  157
# 4             1/10/2017  217
# ...                 ...  ...
# 1172           9/8/2016  206
# 1173           9/8/2017  285
# 1174           9/9/2015  243
# 1175           9/9/2016  236
# 1176           9/9/2017  213
#
# [1177 rows x 2 columns]

# %%
df4.columns = ['date' , 'numCrimes']
df4
# Out:
#            date  numCrimes
# 0      1/1/2016        280
# 1      1/1/2017        209
# 2      1/1/2018        212
# 3     1/10/2016        157
# 4     1/10/2017        217
# ...         ...        ...
# 1172   9/8/2016        206
# 1173   9/8/2017        285
# 1174   9/9/2015        243
# 1175   9/9/2016        236
# 1176   9/9/2017        213
#
# [1177 rows x 2 columns]

# %%
merge = pd.merge(df2, df4, left_on='OCCURRED_ON_DATE.1', right_on='date',)

# %%
merge
# Out:
#       Temp_High  rain OCCURRED_ON_DATE.1  Temp_low  snow       date  numCrimes
# 0          80.0  0.00           9/2/2018      64.0   0.0   9/2/2018        189
# 1          70.0  0.00          8/21/2018      64.9   0.0  8/21/2018        219
# 2         100.0  0.00           9/3/2018      73.0   0.0   9/3/2018        144
# 3          70.0  0.00           9/1/2018      63.0   0.0   9/1/2018        213
# 4          70.0  0.00          8/31/2018      63.0   0.0  8/31/2018        235
# ...         ...   ...                ...       ...   ...        ...        ...
# 1172       80.0  0.14          7/18/2015      64.0   0.0  7/18/2015        191
# 1173       60.0  1.43          6/28/2015      52.0   0.0  6/28/2015        177
# 1174       80.0   NaN          7/26/2015      63.0   0.0  7/26/2015        155
# 1175       70.0   NaN          6/16/2015      55.9   0.0  6/16/2015        193
# 1176       80.0  0.00          6/24/2015      66.9   0.0  6/24/2015        218
#
# [1177 rows x 7 columns]

# %%
import numpy as np
data = merge.drop('OCCURRED_ON_DATE.1', axis=1)
data['numCrimes'] = data['numCrimes'].round(-2)
data.replace([np.inf, np.inf], np.nan, inplace=True)
data.dropna(inplace=True)

data
# Out:
#       Temp_High  rain  Temp_low  snow       date  numCrimes
# 0          80.0  0.00      64.0   0.0   9/2/2018        200
# 1          70.0  0.00      64.9   0.0  8/21/2018        200
# 2         100.0  0.00      73.0   0.0   9/3/2018        100
# 3          70.0  0.00      63.0   0.0   9/1/2018        200
# 4          70.0  0.00      63.0   0.0  8/31/2018        200
# ...         ...   ...       ...   ...        ...        ...
# 1170       80.0  0.00      64.9   0.0   8/5/2015        200
# 1171       90.0  0.00      68.0   0.0   8/2/2015        200
# 1172       80.0  0.14      64.0   0.0  7/18/2015        200
# 1173       60.0  1.43      52.0   0.0  6/28/2015        200
# 1176       80.0  0.00      66.9   0.0  6/24/2015        200
#
# [988 rows x 6 columns]

# %%
y = data["numCrimes"]
X = data.loc[:, ["Temp_High", 'rain', 'snow', 'Temp_low']]

print("X:", X.shape)
print("Y:", y.shape)
# Out:
# X: (988, 4)
# Y: (988,)

# %%
from sklearn import metrics

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=200, random_state=1)

# %%
from sklearn.linear_model  import LogisticRegression

logreg= LogisticRegression(solver='lbfgs', max_iter=100)

logreg.fit(X_train,y_train)
# Out:
# C:\Users\19138\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

y_pred=logreg.predict(X_test)

print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.9

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[  0   6   0]
#  [  0 180   0]
#  [  0  14   0]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          100       0.00      0.00      0.00         6
#          200       0.90      1.00      0.95       180
#          300       0.00      0.00      0.00        14
#
#     accuracy                           0.90       200
#    macro avg       0.30      0.33      0.32       200
# weighted avg       0.81      0.90      0.85       200
# C:\Users\19138\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\19138\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\19138\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X, y)
y_pred = knn.predict(X)
print(metrics.accuracy_score(y, y_pred))
# Out:
# 0.9038461538461539

# %%
neighbors = list(range(1,50))

# %%
score = []

# %%
for i in neighbors:
    clf = KNeighborsClassifier(n_neighbors = i)
    clf.fit(X_train, y_train)
    preds_neighbors = clf.predict(X_test)
    score.append (accuracy_score(y_true = y_test, y_pred = preds_neighbors))

# %%
import matplotlib.pyplot as plt
plt.plot(neighbors, score)
plt.xlabel('value of k for KNN')
plt.ylabel('Testing accuracy')
# Out:
# Text(0, 0.5, 'Testing accuracy')

# %%
from sklearn.model_selection import train_test_split
var_train, var_test, res_train, res_test = train_test_split(X, y, test_size = 500)

# %%
from sklearn import tree

decision_tree = tree.DecisionTreeClassifier()
decision_tree = decision_tree.fit(var_train, res_train)

# %%
from sklearn.metrics import accuracy_score
res_pred = decision_tree.predict(var_test)
score = accuracy_score(res_test, res_pred)

# %%
score
# Out:
# 0.82
