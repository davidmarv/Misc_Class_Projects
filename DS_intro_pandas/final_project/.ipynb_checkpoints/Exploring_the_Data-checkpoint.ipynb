# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('CleanedCrimeData.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0           0      I182070945           619               Larceny
# 1           1      I182070943          1402             Vandalism
# 2           2      I182070941          3410                 Towed
# 3           3      I182070940          3114  Investigate Property
# 4           4      I182070938          3114  Investigate Property
#
#     OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  YEAR  MONTH  ...  \
# 0    LARCENY ALL OTHERS      D14            808      NaN  2018      9  ...
# 1             VANDALISM      C11            347      NaN  2018      8  ...
# 2   TOWED MOTOR VEHICLE       D4            151      NaN  2018      9  ...
# 3  INVESTIGATE PROPERTY       D4            272      NaN  2018      9  ...
# 4  INVESTIGATE PROPERTY       B3            421      NaN  2018      9  ...
#
#   HOUR       STREET                     Location OCCURRED_ON_DATE.1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255006 entries, 0 to 255005
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           255006 non-null  int64
#  1   INCIDENT_NUMBER      255006 non-null  object
#  2   OFFENSE_CODE         255006 non-null  int64
#  3   OFFENSE_CODE_GROUP   255006 non-null  object
#  4   OFFENSE_DESCRIPTION  255006 non-null  object
#  5   DISTRICT             253559 non-null  object
#  6   REPORTING_AREA       255006 non-null  object
#  7   SHOOTING             398 non-null     object
#  8   YEAR                 255006 non-null  int64
#  9   MONTH                255006 non-null  int64
#  10  DAY_OF_WEEK          255006 non-null  object
#  11  HOUR                 255006 non-null  int64
#  12  STREET               246846 non-null  object
#  13  Location             255006 non-null  object
#  14  OCCURRED_ON_DATE.1   255006 non-null  object
# ...

# %%
import seaborn

# %%
seaborn.set(rc={'figure.figsize':(12,9)})

# %%
g=seaborn.pairplot(df, x_vars=["DISTRICT","OFFENSE_CODE_GROUP"], y_vars=["DISTRICT","OFFENSE_CODE_GROUP"])
g.fig.set_size_inches(15,15)
# Out:
# C:\Users\19138\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
seaborn.countplot(data=df, x='YEAR');

# %%
ax=seaborn.countplot(data=df, y='OFFENSE_CODE_GROUP');
ax=ax.bar_label(ax.containers[0])

# %%
g=seaborn.pairplot(df, x_vars=["DISTRICT","Temp_High","rain"], y_vars=["DISTRICT","Temp_High","rain"])
g.fig.set_size_inches(30,30)

# %%
seaborn.countplot(data=df, y='rain');

# %%
seaborn.countplot(data=df, y='Temp_High');

# %%
seaborn.countplot(data=df, x='DISTRICT');

# %%
H_data = df.loc[df["Temp_High"]>=55,:]
L_data = df.loc[df["Temp_High"]<55,:]

# %%
seaborn.countplot(data=H_data, x='DISTRICT');

# %%
seaborn.countplot(data=L_data, x='DISTRICT');

# %%
from pylab import rcParams
rcParams["figure.figsize"] = 30,10
order = df['OFFENSE_CODE_GROUP'].value_counts().head(10).index
seaborn.countplot(data = df, x='OFFENSE_CODE_GROUP',hue='DISTRICT', order = order);

# %%
from pylab import rcParams
rcParams["figure.figsize"] = 30,10
df2 = df
df2['Temp_High'] = df2['Temp_High'].round(-1)
df2.head(20)
# Out:
#     Unnamed: 0 INCIDENT_NUMBER  OFFENSE_CODE  \
# 0            0      I182070945           619
# 1            1      I182070943          1402
# 2            2      I182070941          3410
# 3            3      I182070940          3114
# 4            4      I182070938          3114
# 5            5      I182070936          3820
# 6            6      I182070933           724
# 7            7      I182070932          3301
# 8            8      I182070931           301
# 9            9      I182070929          3301
# 10          10      I182070928          3301
# 11          11      I182070927          3114
# 12          12      I182070923          3108
# 13          13      I182070922          2647
# 14          14      I182070921          3201
# 15          15      I182070920          3006
# 16          16      I182070919          3301
# 17          17      I182070918          3305
# 18          18      I182070917          2647
# 19          19      I182070915           614
#
# ...

# %% [markdown]
# order = df['OFFENSE_CODE_GROUP'].value_counts().head(10).index
# seaborn.countplot(data = df, x='OFFENSE_CODE_GROUP',hue='Temp_High', order = order);

# %%
order = df['OFFENSE_CODE_GROUP'].value_counts().head(10).index
seaborn.countplot(data = df2, x='OFFENSE_CODE_GROUP',hue='Temp_High', order = order);
